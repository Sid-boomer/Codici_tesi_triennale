# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.ticker import ScalarFormatter, FuncFormatter

# Funzione per formattare i valori dell'asse y senza decimali
def integer_formatter(x, pos):
    if x.is_integer():
        return f'{int(x)}'  # Mostra solo numeri interi
    else:
        return f'{x}'
    
# Carica il file in un DataFrame, specificando i nomi delle colonne
data = pd.read_csv('Data_settembre\GL7-240924_132821.txt', sep='\t')

# Estrai le colonne di interesse
time = data['TIMESTAMP']  # La prima colonna come asse x
components = data.columns[1:8]  # Le sette colonne successive


print(data['TIMESTAMP'].min())
print(data['TIMESTAMP'].max())

'''# Crea il grafico
plt.figure(figsize=(12, 6))

# Ciclo sulle componenti, assegnando un colore diverso per ciascuna
for i, component in enumerate(components):
    plt.plot(time, data[component], label=component)

# Configura il grafico
plt.xlabel('Tempo (unità arbitrarie)')
plt.ylabel('Temperatura (K)')
plt.title('Ciclo di raffreddamento')
plt.yscale('log')
plt.legend()
plt.grid(True, which="both")

plt.gca().yaxis.set_major_formatter(FuncFormatter(integer_formatter))
#plt.gca().yaxis.get_major_formatter().set_scientific(False)
plt.yticks([ 0.1, 1, 10, 100, 1000])  # Imposta i tick sull'asse y a partire da 0.01
#plt.ylim(0.01, 1000)  # Imposta i limiti dell'asse y per partire da 0.01

plt.show()'''


# ZOOM
plt.figure(figsize=(12, 6))

for i, component in enumerate(components):
    plt.plot(time, data[component], label=component)


plt.xlabel('Tempo (unità arbitrarie)')
plt.ylabel('Temperatura (K)')
plt.title('')
plt.yscale('log')
plt.legend()
plt.grid(True, which="both")
plt.xlim(data['TIMESTAMP'].min()+158000, data['TIMESTAMP'].max()-1011000)
plt.gca().yaxis.set_major_formatter(FuncFormatter(integer_formatter))
#plt.gca().yaxis.get_major_formatter().set_scientific(False)
plt.yticks([ 0.1, 1, 10, 100])  # Imposta i tick sull'asse y a partire da 0.01
#plt.ylim(0.01, 1000)  # Imposta i limiti dell'asse y per partire da 0.01
plt.savefig("Ciclo_esempio.png", format="png")
plt.show()
# Out:
# <>:13: SyntaxWarning: invalid escape sequence '\G'
# <>:13: SyntaxWarning: invalid escape sequence '\G'
# C:\Users\simon\AppData\Local\Temp\ipykernel_9636\2872356435.py:13: SyntaxWarning: invalid escape sequence '\G'
#   data = pd.read_csv('Data_settembre\GL7-240924_132821.txt', sep='\t')
# 1727191705
# 1728372152

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.ticker import ScalarFormatter, FuncFormatter

# Funzione per formattare i valori dell'asse y senza decimali
def integer_formatter(x, pos):
    if x.is_integer():
        return f'{int(x)}'  # Mostra solo numeri interi
    else:
        return f'{x}'
    
# Carica il file in un DataFrame, specificando i nomi delle colonne
data = pd.read_csv('Data_settembre\GL7-241008_090350.txt', sep='\t')

# Estrai le colonne di interesse
time = data['TIMESTAMP']  # La prima colonna come asse x
components = data.columns[1:8]  # Le sette colonne successive


print(data['TIMESTAMP'].min())
print(data['TIMESTAMP'].max())

# Crea il grafico
plt.figure(figsize=(12, 6))

# Ciclo sulle componenti, assegnando un colore diverso per ciascuna
for i, component in enumerate(components):
    plt.plot(time, data[component], label=component)

# Configura il grafico
plt.xlabel('Tempo (unità arbitrarie)')
plt.ylabel('Temperatura (K)')
plt.title('Ciclo di raffreddamento')
plt.yscale('log')
plt.legend()
plt.grid(True, which="both")

plt.gca().yaxis.set_major_formatter(FuncFormatter(integer_formatter))
#plt.gca().yaxis.get_major_formatter().set_scientific(False)
plt.yticks([ 0.1, 1, 10, 100, 1000])  # Imposta i tick sull'asse y a partire da 0.01
#plt.ylim(0.01, 1000)  # Imposta i limiti dell'asse y per partire da 0.01

plt.show()


# ZOOM
plt.figure(figsize=(12, 6))

for i, component in enumerate(components):
    plt.plot(time, data[component], label=component)


plt.xlabel('Tempo (unità arbitrarie)')
plt.ylabel('Temperatura (K)')
plt.title('')
plt.yscale('log')
plt.legend()
plt.grid(True, which="both")
plt.xlim(data['TIMESTAMP'].min()+710000, data['TIMESTAMP'].max()-42000)
plt.gca().yaxis.set_major_formatter(FuncFormatter(integer_formatter))
#plt.gca().yaxis.get_major_formatter().set_scientific(False)
plt.yticks([ 0.1, 1, 10, 100])  # Imposta i tick sull'asse y a partire da 0.01
#plt.ylim(0.01, 1000)  # Imposta i limiti dell'asse y per partire da 0.01
plt.savefig("Ciclo_esempio.png", format="png")
plt.show()
# Out:
# <>:13: SyntaxWarning: invalid escape sequence '\G'
# <>:13: SyntaxWarning: invalid escape sequence '\G'
# C:\Users\simon\AppData\Local\Temp\ipykernel_9636\270838815.py:13: SyntaxWarning: invalid escape sequence '\G'
#   data = pd.read_csv('Data_settembre\GL7-241008_090350.txt', sep='\t')
# 1728385435
# 1729155053

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.ticker import ScalarFormatter, FuncFormatter

# Funzione per formattare i valori dell'asse y senza decimali
def integer_formatter(x, pos):
    if x.is_integer():
        return f'{int(x)}'  # Mostra solo numeri interi
    else:
        return f'{x}'
    
# Carica il file in un DataFrame, specificando i nomi delle colonne
data = pd.read_csv('Data_settembre\GL7-241017_072806.txt', sep='\t')

# Estrai le colonne di interesse
time = data['TIMESTAMP']  # La prima colonna come asse x
components = data.columns[1:8]  # Le sette colonne successive


print(data['TIMESTAMP'].min())
print(data['TIMESTAMP'].max())

'''# Crea il grafico
plt.figure(figsize=(12, 6))

# Ciclo sulle componenti, assegnando un colore diverso per ciascuna
for i, component in enumerate(components):
    plt.plot(time, data[component], label=component)

# Configura il grafico
plt.xlabel('Tempo (unità arbitrarie)')
plt.ylabel('Temperatura (K)')
plt.title('Ciclo di raffreddamento')
plt.yscale('log')
plt.legend()
plt.grid(True, which="both")

plt.gca().yaxis.set_major_formatter(FuncFormatter(integer_formatter))
#plt.gca().yaxis.get_major_formatter().set_scientific(False)
plt.yticks([ 0.1, 1, 10, 100, 1000])  # Imposta i tick sull'asse y a partire da 0.01
#plt.ylim(0.01, 1000)  # Imposta i limiti dell'asse y per partire da 0.01

plt.show()'''


# ZOOM
plt.figure(figsize=(12, 6))

for i, component in enumerate(components):
    plt.plot(time, data[component], label=component)


plt.xlabel('Tempo (unità arbitrarie)')
plt.ylabel('Temperatura (K)')
plt.title('')
plt.yscale('log')
plt.legend()
plt.grid(True, which="both")
plt.xlim(data['TIMESTAMP'].min()+25500, data['TIMESTAMP'].max()-416000)
plt.gca().yaxis.set_major_formatter(FuncFormatter(integer_formatter))
#plt.gca().yaxis.get_major_formatter().set_scientific(False)
plt.yticks([ 0.1, 1, 10, 100])  # Imposta i tick sull'asse y a partire da 0.01
#plt.ylim(0.01, 1000)  # Imposta i limiti dell'asse y per partire da 0.01
plt.show()
# Out:
# <>:13: SyntaxWarning: invalid escape sequence '\G'
# <>:13: SyntaxWarning: invalid escape sequence '\G'
# C:\Users\simon\AppData\Local\Temp\ipykernel_9636\2361520470.py:13: SyntaxWarning: invalid escape sequence '\G'
#   data = pd.read_csv('Data_settembre\GL7-241017_072806.txt', sep='\t')
# 1729157291
# 1729604176

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.ticker import ScalarFormatter, FuncFormatter

# Funzione per formattare i valori dell'asse y senza decimali
def integer_formatter(x, pos):
    if x.is_integer():
        return f'{int(x)}'  # Mostra solo numeri interi
    else:
        return f'{x}'
    
# Carica il file in un DataFrame, specificando i nomi delle colonne
data = pd.read_csv('Data_settembre\GL7-241022_182219.txt', sep='\t')

# Estrai le colonne di interesse
time = data['TIMESTAMP']  # La prima colonna come asse x
components = data.columns[1:8]  # Le sette colonne successive


print(data['TIMESTAMP'].min())
print(data['TIMESTAMP'].max())

# Crea il grafico
plt.figure(figsize=(12, 6))

# Ciclo sulle componenti, assegnando un colore diverso per ciascuna
for i, component in enumerate(components):
    plt.plot(time, data[component], label=component)

# Configura il grafico
plt.xlabel('Tempo (unità arbitrarie)')
plt.ylabel('Temperatura (K)')
plt.title('Ciclo di raffreddamento')
plt.yscale('log')
plt.legend()
plt.grid(True, which="both")

plt.gca().yaxis.set_major_formatter(FuncFormatter(integer_formatter))
#plt.gca().yaxis.get_major_formatter().set_scientific(False)
plt.yticks([ 0.1, 1, 10, 100, 1000])  # Imposta i tick sull'asse y a partire da 0.01
#plt.ylim(0.01, 1000)  # Imposta i limiti dell'asse y per partire da 0.01

plt.show()


# ZOOM
plt.figure(figsize=(12, 6))

for i, component in enumerate(components):
    plt.plot(time, data[component], label=component)


plt.xlabel('Tempo (unità arbitrarie)')
plt.ylabel('Temperatura (K)')
plt.title('')
plt.yscale('log')
plt.legend()
plt.grid(True, which="both")
plt.xlim(data['TIMESTAMP'].min(), data['TIMESTAMP'].max()-700000)

plt.gca().yaxis.set_major_formatter(FuncFormatter(integer_formatter))
#plt.gca().yaxis.get_major_formatter().set_scientific(False)
plt.yticks([ 0.1, 1, 10, 100])  # Imposta i tick sull'asse y a partire da 0.01
#plt.ylim(0.01, 1000)  # Imposta i limiti dell'asse y per partire da 0.01

plt.show()
# Out:
# <>:13: SyntaxWarning: invalid escape sequence '\G'
# <>:13: SyntaxWarning: invalid escape sequence '\G'
# C:\Users\simon\AppData\Local\Temp\ipykernel_4352\2554510523.py:13: SyntaxWarning: invalid escape sequence '\G'
#   data = pd.read_csv('Data_settembre\GL7-241022_182219.txt', sep='\t')
# 1729628544
# 1730390478

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.ticker import ScalarFormatter, FuncFormatter

# Funzione per formattare i valori dell'asse y senza decimali
def integer_formatter(x, pos):
    if x.is_integer():
        return f'{int(x)}'  # Mostra solo numeri interi
    else:
        return f'{x}'
    
# Carica il file in un DataFrame, specificando i nomi delle colonne
data = pd.read_csv('Data_settembre\GL7-241031_145803.txt', sep='\t')

# Estrai le colonne di interesse
time = data['TIMESTAMP']  # La prima colonna come asse x
components = data.columns[1:8]  # Le sette colonne successive


# Crea il grafico
plt.figure(figsize=(12, 6))

# Ciclo sulle componenti, assegnando un colore diverso per ciascuna
for i, component in enumerate(components):
    plt.plot(time, data[component], label=component)

# Configura il grafico
plt.xlabel('Tempo (unità arbitrarie)')
plt.ylabel('Temperatura (K)')
plt.title('Ciclo di raffreddamento')
plt.yscale('log')
plt.legend()
plt.grid(True, which="both")

plt.gca().yaxis.set_major_formatter(FuncFormatter(integer_formatter))
#plt.gca().yaxis.get_major_formatter().set_scientific(False)
plt.yticks([ 0.1, 1, 10, 100, 1000])  # Imposta i tick sull'asse y a partire da 0.01
#plt.ylim(0.01, 1000)  # Imposta i limiti dell'asse y per partire da 0.01

plt.show()


# ZOOM
plt.figure(figsize=(12, 6))

for i, component in enumerate(components):
    plt.plot(time, data[component], label=component)


plt.xlabel('Tempo (unità arbitrarie)')
plt.ylabel('Temperatura (K)')
plt.title('')
plt.yscale('log')
plt.legend()
plt.grid(True, which="both")
plt.xlim(data['TIMESTAMP'].min()+8000, data['TIMESTAMP'].max())
plt.gca().yaxis.set_major_formatter(FuncFormatter(integer_formatter))
#plt.gca().yaxis.get_major_formatter().set_scientific(False)
plt.yticks([ 0.1, 1, 10, 100])  # Imposta i tick sull'asse y a partire da 0.01
#plt.ylim(0.01, 1000)  # Imposta i limiti dell'asse y per partire da 0.01
plt.show()

print(data['TIMESTAMP'].min())
print(data['TIMESTAMP'].max())
# Out:
# <>:13: SyntaxWarning: invalid escape sequence '\G'
# <>:13: SyntaxWarning: invalid escape sequence '\G'
# C:\Users\simon\AppData\Local\Temp\ipykernel_9636\894033741.py:13: SyntaxWarning: invalid escape sequence '\G'
#   data = pd.read_csv('Data_settembre\GL7-241031_145803.txt', sep='\t')
# 1730393888
# 1730406180

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.ticker import ScalarFormatter, FuncFormatter

# Funzione per formattare i valori dell'asse y senza decimali
def integer_formatter(x, pos):
    if x.is_integer():
        return f'{int(x)}'  # Mostra solo numeri interi
    else:
        return f'{x}'
    
# Carica il file in un DataFrame, specificando i nomi delle colonne
data = pd.read_csv('Data_settembre\GL7-241031_182417.txt', sep='\t')

# Estrai le colonne di interesse
time = data['TIMESTAMP']  # La prima colonna come asse x
components = data.columns[1:8]  # Le sette colonne successive


# Crea il grafico
plt.figure(figsize=(12, 6))

# Ciclo sulle componenti, assegnando un colore diverso per ciascuna
for i, component in enumerate(components):
    plt.plot(time, data[component], label=component)

# Configura il grafico
plt.xlabel('Tempo (unità arbitrarie)')
plt.ylabel('Temperatura (K)')
plt.title('Ciclo di raffreddamento')
plt.yscale('log')
plt.legend()
plt.grid(True, which="both")

plt.gca().yaxis.set_major_formatter(FuncFormatter(integer_formatter))
#plt.gca().yaxis.get_major_formatter().set_scientific(False)
plt.yticks([ 0.1, 1, 10, 100, 1000])  # Imposta i tick sull'asse y a partire da 0.01
#plt.ylim(0.01, 1000)  # Imposta i limiti dell'asse y per partire da 0.01

plt.show()


# ZOOM
plt.figure(figsize=(12, 6))

for i, component in enumerate(components):
    plt.plot(time, data[component], label=component)


plt.xlabel('Tempo (unità arbitrarie)')
plt.ylabel('Temperatura (K)')
plt.title('')
plt.yscale('log')
plt.legend()
plt.grid(True, which="both")
plt.xlim(data['TIMESTAMP'].min()+1101000, data['TIMESTAMP'].max())
plt.gca().yaxis.set_major_formatter(FuncFormatter(integer_formatter))
#plt.gca().yaxis.get_major_formatter().set_scientific(False)
plt.yticks([ 0.1, 1, 10, 100])  # Imposta i tick sull'asse y a partire da 0.01
#plt.ylim(0.01, 1000)  # Imposta i limiti dell'asse y per partire da 0.01
plt.savefig("Ciclo_finale.pdf", format = "pdf")
plt.show()

print(data['TIMESTAMP'].min())
print(data['TIMESTAMP'].max())
# Out:
# <>:13: SyntaxWarning: invalid escape sequence '\G'
# <>:13: SyntaxWarning: invalid escape sequence '\G'
# C:\Users\simon\AppData\Local\Temp\ipykernel_9636\2576437693.py:13: SyntaxWarning: invalid escape sequence '\G'
#   data = pd.read_csv('Data_settembre\GL7-241031_182417.txt', sep='\t')
# 1730406261
# 1731516071

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter
import glob
import os

# Funzione per formattare i valori dell'asse y senza decimali
def integer_formatter(x, pos):
    if x.is_integer():
        return f'{int(x)}'  # Mostra solo numeri interi
    else:
        return f'{x}'

# Percorso della cartella contenente i file
folder_path = 'Data_settembre'

# Cerca tutti i file .txt nella cartella
file_list = glob.glob(os.path.join(folder_path, '*.txt'))

# Itera su ciascun file trovato
for file_path in file_list:
    # Carica il file in un DataFrame
    data = pd.read_csv(file_path, sep='\t')

    # Estrai le colonne di interesse
    time = data['TIMESTAMP']  # La prima colonna come asse x
    components = data.columns[1:8]  # Le sette colonne successive

    # Crea il grafico per ogni file
    plt.figure(figsize=(12, 6))

    # Ciclo sulle componenti, assegnando un colore diverso per ciascuna
    for i, component in enumerate(components):
        plt.plot(time, data[component], label=component)

    # Configura il grafico
    plt.xlabel('Tempo (unità arbitrarie)')
    plt.ylabel('Temperatura (K)')
    plt.title(f'Ciclo di raffreddamento - {os.path.basename(file_path)}')
    plt.yscale('log')
    plt.legend()
    plt.grid(True, which="both")

    # Imposta i tick dell'asse y senza notazione scientifica
    plt.gca().yaxis.set_major_formatter(FuncFormatter(integer_formatter))
    plt.yticks([0.1, 1, 10, 100, 1000])  # Imposta i tick sull'asse y
    plt.ylim(0.1, 1000)  # Imposta i limiti dell'asse y
    
    plt.show()


    # Stampa i minimi e massimi per il timestamp del file attuale
    print(f"{os.path.basename(file_path)}: TIMESTAMP min = {data['TIMESTAMP'].min()}, TIMESTAMP max = {data['TIMESTAMP'].max()}")
# Out:
# GL7-240924_132752.txt: TIMESTAMP min = 1727191676, TIMESTAMP max = 1727191676
# GL7-240924_132821.txt: TIMESTAMP min = 1727191705, TIMESTAMP max = 1728372152
# GL7-241008_073724.txt: TIMESTAMP min = 1728380248, TIMESTAMP max = 1728380248
# GL7-241008_090350.txt: TIMESTAMP min = 1728385435, TIMESTAMP max = 1729155053
# GL7-241017_072456.txt: TIMESTAMP min = 1729157101, TIMESTAMP max = 1729157265
# GL7-241017_072748.txt: TIMESTAMP min = 1729157273, TIMESTAMP max = 1729157279
# GL7-241017_072806.txt: TIMESTAMP min = 1729157291, TIMESTAMP max = 1729604176
# GL7-241022_113629.txt: TIMESTAMP min = 1729604193, TIMESTAMP max = 1729604193
# GL7-241022_113708.txt: TIMESTAMP min = 1729604232, TIMESTAMP max = 1729604232
# GL7-241022_113926.txt: TIMESTAMP min = 1729604371, TIMESTAMP max = 1729625083
# GL7-241022_182219.txt: TIMESTAMP min = 1729628544, TIMESTAMP max = 1730390478
# GL7-241031_145803.txt: TIMESTAMP min = 1730393888, TIMESTAMP max = 1730406180
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter
import glob
import os

# Funzione per formattare i valori dell'asse y senza decimali
def integer_formatter(x, pos):
    if x.is_integer():
        return f'{int(x)}'  # Mostra solo numeri interi
    else:
        return f'{x}'

# Percorso della cartella contenente i file
folder_path = 'Data/Novembre'

# Cerca tutti i file .txt nella cartella
file_list = glob.glob(os.path.join(folder_path, '*.txt'))

# Itera su ciascun file trovato
for file_path in file_list:
    # Carica il file in un DataFrame
    data = pd.read_csv(file_path, sep='\t')

    # Estrai le colonne di interesse: TIMESTAMP e le colonne con dati di temperatura
    columns_to_plot = [col for idx, col in enumerate(data.columns) if idx == 0 or idx % 2 == 1]
    data_to_plot = data[columns_to_plot]

    # Estrai TIMESTAMP e le colonne di temperatura
    time = data_to_plot.iloc[:, 0]  # TIMESTAMP
    temperatures = data_to_plot.iloc[:, 1:]  # Colonne di temperatura

    # Crea il grafico per ogni file
    plt.figure(figsize=(12, 6))

    # Ciclo sulle colonne di temperatura, assegnando un colore diverso per ciascuna
    for column in temperatures.columns:
        plt.plot(time, data_to_plot[column], label=column)

    # Configura il grafico
    plt.xlabel('Tempo (unità arbitrarie)')
    plt.ylabel('Temperatura (K)')
    plt.title(f'Ciclo di raffreddamento - {os.path.basename(file_path)}')
    plt.yscale('log')
    plt.legend()
    plt.grid(True, which="both")

    # Imposta i tick dell'asse y senza notazione scientifica
    plt.gca().yaxis.set_major_formatter(FuncFormatter(integer_formatter))
    plt.yticks([0.1, 1, 10, 100, 1000])  # Imposta i tick sull'asse y
    #plt.ylim(0.1, 1000)  # Imposta i limiti dell'asse y

    plt.show()

    # Stampa i minimi e massimi per il timestamp del file attuale
    print(f"{os.path.basename(file_path)}: TIMESTAMP min = {data['TIMESTAMP'].min()}, TIMESTAMP max = {data['TIMESTAMP'].max()}")
# Out:
# GL7-241115_111402.txt: TIMESTAMP min = 1731676446, TIMESTAMP max = 1731676455
# GL7-241115_111818.txt: TIMESTAMP min = 1731676702, TIMESTAMP max = 1731676707
# GL7-241115_112008.txt: TIMESTAMP min = 1731676812, TIMESTAMP max = 1731676826
# GL7-241115_112433.txt: TIMESTAMP min = 1731677077, TIMESTAMP max = 1731677094
# GL7-241115_112706.txt: TIMESTAMP min = 1731677230, TIMESTAMP max = 1731677234
# GL7-241115_113736.txt: TIMESTAMP min = 1731677861, TIMESTAMP max = 1731677868
# GL7-241115_114648.txt: TIMESTAMP min = 1731678412, TIMESTAMP max = 1731678419
# GL7-241115_114923.txt: TIMESTAMP min = 1731678568, TIMESTAMP max = 1731678624
# GL7-241115_115058.txt: TIMESTAMP min = 1731678662, TIMESTAMP max = 1731678804
# GL7-241115_120020.txt: TIMESTAMP min = 1731679224, TIMESTAMP max = 1731679229
# GL7-241118_134350.txt: TIMESTAMP min = 1731944634, TIMESTAMP max = 1732284464
# GL7-241122_125653.txt: TIMESTAMP min = 1732287418, TIMESTAMP max = 1732287418
# ...
