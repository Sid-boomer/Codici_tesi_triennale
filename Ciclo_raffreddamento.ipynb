# %%
import pandas as pd
import matplotlib.pyplot as plt

# Carica il file in un DataFrame, specificando i nomi delle colonne
data = pd.read_csv('Data\GL7-241022_182219.txt', sep='\t')

# Estrai le colonne di interesse
time = data['TIMESTAMP']  # La prima colonna come asse x
components = data.columns[1:8]  # Le sette colonne successive


# Crea il grafico
plt.figure(figsize=(12, 6))

# Ciclo sulle componenti, assegnando un colore diverso per ciascuna
for i, component in enumerate(components):
    plt.plot(time, data[component], label=component)

# Configura il grafico
plt.xlabel('Tempo (unità arbitrarie)')
plt.ylabel('Temperatura (K)')
plt.title('Ciclo di raffreddamento')
plt.yscale('log')
plt.xlim(1730250000, 1730390478)
plt.ylim(0, 100)

print(data['TIMESTAMP'].min())
print(data['TIMESTAMP'].max())

plt.legend()
plt.grid(True, which="both")

# Mostra il grafico
plt.show()
# Out:
# <>:5: SyntaxWarning: invalid escape sequence '\G'
# <>:5: SyntaxWarning: invalid escape sequence '\G'
# C:\Users\simon\AppData\Local\Temp\ipykernel_8436\548614253.py:5: SyntaxWarning: invalid escape sequence '\G'
#   data = pd.read_csv('Data\GL7-241022_182219.txt', sep='\t')
# C:\Users\simon\AppData\Local\Temp\ipykernel_8436\548614253.py:25: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   plt.ylim(0, 100)
# 1729628544
# 1730390478

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Carica il file in un DataFrame, specificando i nomi delle colonne
data = pd.read_csv('Data\GL7-241008_090350.txt', sep='\t')

# Estrai le colonne di interesse
time = data['TIMESTAMP']  # La prima colonna come asse x
components = data.columns[1:8]  # Le sette colonne successive


# Crea il grafico
plt.figure(figsize=(12, 6))

# Ciclo sulle componenti, assegnando un colore diverso per ciascuna
for i, component in enumerate(components):
    plt.plot(time, data[component], label=component)

# Configura il grafico
plt.xlabel('Tempo (unità arbitrarie)')
plt.ylabel('Temperatura (K)')
plt.title('Ciclo di raffreddamento')
plt.yscale('log')
plt.xlim(1729010000, 1729120053)
#plt.ylim(0, 100)

print(data['TIMESTAMP'].min())
print(data['TIMESTAMP'].max())

plt.legend()
plt.grid(True, which="both")

# Mostra il grafico
plt.show()
# Out:
# <>:5: SyntaxWarning: invalid escape sequence '\G'
# <>:5: SyntaxWarning: invalid escape sequence '\G'
# C:\Users\simon\AppData\Local\Temp\ipykernel_8436\2449414621.py:5: SyntaxWarning: invalid escape sequence '\G'
#   data = pd.read_csv('Data\GL7-241008_090350.txt', sep='\t')
# 1728385435
# 1729155053
